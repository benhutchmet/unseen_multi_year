# %%
import os
import sys
import glob

import pandas as pd
import xarray as xr

# %%
# set up the path to the parquet file
mix2030_path = "/home/users/benhutch/unseen_multi_year/power_system/MIX2030_METIS_daily.parquet"

# %%
! pip install pyarrow
! pip install fastparquet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for fastparquet from https://files.pythonhosted.org/packages/3e/a4/2ff7b6688d614bef88d2b2a14a5479cbc310d7d296e738d71f182eba2f30/fastparquet-2024.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
# Using cached fastparquet-2024.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
# ...

# %%
# import the data using pandas
mix2030 = pd.read_parquet(mix2030_path)

# %%
mix2030.head()
# Out:
#   country  TC  yday   demand  peak_demand  avg_price  curtailed_MWh  \
# 0      AL  00     1  22146.5       1187.3  68.977715            0.0
# 1      AL  00     2  23071.8       1183.7  67.541286           -0.0
# 2      AL  00     3  23410.4       1273.4  65.528980           -0.0
# 3      AL  00     4  24482.4       1347.7  70.506577            0.0
# 4      AL  00     5  24702.4       1358.0  72.995689           -0.0
#
#    co2_emissions  co2_intens      vres_gen  sun_gen     hydro_gen  wind_gen  \
# 0            NaN         NaN  12997.727370   1489.5  23467.333585    2727.8
# 1            NaN         NaN  11846.748617    592.5  22252.871607    2224.2
# 2            NaN         NaN  10984.488514   1453.0  20948.905861     972.6
# 3            NaN         NaN  10395.777890   1560.5  33215.994494     401.2
# 4            NaN         NaN   9749.698849   1547.5  40872.509114     226.8
#
#      import_MWh    export_MWh        storage      all_prod
# ...

# %%
#
